# %% [markdown]
# ## Anime Recommender System — Autoencoder Demo
#
# This notebook serves as a quick, interactive showcase of how the recommender system works internally, specifically demonstrating how to load a pre-trained PyTorch autoencoder and generate anime recommendations for a given user.

# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath("../src"))

from predict_recommendations import recommend

pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", None)

# %% [markdown]
# - Set `user_idx` to the user you want to generate recommendations for.
# - Optionally set `N` to the number of top recommendations.

# %%
df = recommend(user_idx=10, N=10)
df
# Out:
#    anime_id                                       title  predicted_score
# 0     22135                     Ping Pong the Animation        10.943513
# 1     30484                               Steins;Gate 0        10.927124
# 2      3701                                       Kaiba        10.924186
# 3      1747                                     Freedom        10.919085
# 4       207                            Lodoss-tou Senki        10.829827
# 5     43608  Kaguya-sama wa Kokurasetai: Ultra Romantic        10.739573
# 6       160                       Ima, Soko ni Iru Boku        10.619179
# 7       914                    Ike! Ina-chuu Takkyuu-bu        10.574389
# 8     50172                          Mob Psycho 100 III        10.551322
# 9       302                         Mirai Shounen Conan        10.531039
